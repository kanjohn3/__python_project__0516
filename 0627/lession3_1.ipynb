# %%
import pandas as pd
import numpy as np

# 讀取 CSV 檔(使用絕對路徑,避免 Notebook 執行目錄不同導致找不到檔案)
dataFrame = pd.read_csv(r'C:\Users\USER\OneDrive\文件\Github\__python_project__0516\0627\各班圖書借閱統計.csv')

# 第 0 列(index 為 0)才是真正的中文欄位名稱,把它設為欄位名
dataFrame.columns = dataFrame.loc[0]

# 刪除第 0 列(已經拿來當欄位名,資料中不需要重複)
dataFrame = dataFrame.drop(0)

# 提示:整理後資料最後面有「合計列」與 4 列說明文字要刪掉
# 先印出 dataFrame 看看那些列的 index 是多少
print(dataFrame)
# 刪除合計列(index 10)與 4 列說明文字(index 11~14)
dataFrame.drop([10, 11, 12, 13, 14], inplace=True)

# 取得目前的列數與欄數
rowCount, columnCount = dataFrame.shape

# 把索引重設為從 0 開始的連續編號
dataFrame.index = range(rowCount)

# 只保留「班級」「學生人數」「借閱冊數」三個欄位
dataFrame1 = dataFrame.reindex(columns=['班級', '學生人數', '借閱冊數'])

print(dataFrame1)
# Out:
# 0           統計年    班級 學生人數  借閱冊數 平均每人借閱
# 1           112  一年甲班   35   420     12
# 2           112  一年乙班   33   264      8
# 3           112  一年丙班   34   510     15
# 4           112  二年甲班   36   288      8
# 5           112  二年乙班   32   480     15
# 6           112  二年丙班   35   245      7
# 7           112  三年甲班   30   600     20
# 8           112  三年乙班   31   372     12
# 9           112  三年丙班   33   198      6
# 10           合計    合計  299  3377   11.3
# 11   資料來源:學校圖書館   NaN  NaN   NaN    NaN
# 12  製表日期:112年6月   NaN  NaN   NaN    NaN
# 13    備註:含寒暑假借閱   NaN  NaN   NaN    NaN
# 14     本表僅供教學使用   NaN  NaN   NaN    NaN
# 0    班級 學生人數 借閱冊數
# 0  一年甲班   35  420
# 1  一年乙班   33  264
# 2  一年丙班   34  510
# 3  二年甲班   36  288
# 4  二年乙班   32  480
# 5  二年丙班   35  245
# 6  三年甲班   30  600
# 7  三年乙班   31  372
# 8  三年丙班   33  198
