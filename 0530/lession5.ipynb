# %%
student_scores = [
    {"姓名": "王小明", "國文分數": 85, "數學分數": 92, "英文分數": 78, "自然分數": 88, "社會分數": 90},
    {"姓名": "李小華", "國文分數": 76, "數學分數": 65, "英文分數": 82, "自然分數": 70, "社會分數": 75},
    {"姓名": "張大同", "國文分數": 90, "數學分數": 88, "英文分數": 95, "自然分數": 92, "社會分數": 89},
    {"姓名": "陳欣怡", "國文分數": 68, "數學分數": 74, "英文分數": 70, "自然分數": 65, "社會分數": 72},
    {"姓名": "林志豪", "國文分數": 82, "數學分數": 80, "英文分數": 85, "自然分數": 84, "社會分數": 81},
    {"姓名": "黃雅婷", "國文分數": 95, "數學分數": 98, "英文分數": 92, "自然分數": 96, "社會分數": 94},
    {"姓名": "吳建宏", "國文分數": 72, "數學分數": 68, "英文分數": 75, "自然分數": 70, "社會分數": 69},
    {"姓名": "蔡佩珊", "國文分數": 88, "數學分數": 85, "英文分數": 90, "自然分數": 87, "社會分數": 86},
    {"姓名": "許家豪", "國文分數": 60, "數學分數": 55, "英文分數": 62, "自然分數": 58, "社會分數": 61},
    {"姓名": "鄭淑芬", "國文分數": 79, "數學分數": 82, "英文分數": 77, "自然分數": 80, "社會分數": 78},
    {"姓名": "謝承翰", "國文分數": 91, "數學分數": 89, "英文分數": 93, "自然分數": 90, "社會分數": 92},
    {"姓名": "郭美玲", "國文分數": 84, "數學分數": 86, "英文分數": 85, "自然分數": 83, "社會分數": 85},
    {"姓名": "曾冠傑", "國文分數": 75, "數學分數": 70, "英文分數": 78, "自然分數": 72, "社會分數": 74},
    {"姓名": "彭詩涵", "國文分數": 96, "數學分數": 94, "英文分數": 97, "自然分數": 95, "社會分數": 96},
    {"姓名": "詹銘宏", "國文分數": 67, "數學分數": 62, "英文分數": 65, "自然分數": 69, "社會分數": 66},
    {"姓名": "盧佳蓉", "國文分數": 83, "數學分數": 81, "英文分數": 84, "自然分數": 82, "社會分數": 83},
    {"姓名": "丁昱翔", "國文分數": 70, "數學分數": 75, "英文分數": 68, "自然分數": 72, "社會分數": 71},
    {"姓名": "蘇婉君", "國文分數": 89, "數學分數": 90, "英文分數": 87, "自然分數": 88, "社會分數": 89},
    {"姓名": "魏廷翰", "國文分數": 93, "數學分數": 95, "英文分數": 91, "自然分數": 94, "社會分數": 92},
    {"姓名": "薛雅筑", "國文分數": 77, "數學分數": 79, "英文分數": 76, "自然分數": 78, "社會分數": 77},
    {"姓名": "何智偉", "國文分數": 86, "數學分數": 84, "英文分數": 88, "自然分數": 85, "社會分數": 87},
    {"姓名": "羅秋玲", "國文分數": 65, "數學分數": 60, "英文分數": 62, "自然分數": 67, "社會分數": 64},
    {"姓名": "江政廷", "國文分數": 80, "數學分數": 83, "英文分數": 81, "自然分數": 79, "社會分數": 82},
    {"姓名": "童郁芬", "國文分數": 94, "數學分數": 92, "英文分數": 95, "自然分數": 93, "社會分數": 94},
    {"姓名": "廖健文", "國文分數": 71, "數學分數": 73, "英文分數": 70, "自然分數": 74, "社會分數": 72},
    {"姓名": "邱美惠", "國文分數": 87, "數學分數": 85, "英文分數": 89, "自然分數": 86, "社會分數": 88},
    {"姓名": "柯文祥", "國文分數": 58, "數學分數": 62, "英文分數": 55, "自然分數": 60, "社會分數": 59},
    {"姓名": "鐘惠萍", "國文分數": 82, "數學分數": 81, "英文分數": 83, "自然分數": 80, "社會分數": 82},
    {"姓名": "尤冠宇", "國文分數": 97, "數學分數": 96, "英文分數": 98, "自然分數": 95, "社會分數": 97},
    {"姓名": "阮詩琴", "國文分數": 69, "數學分數": 66, "英文分數": 71, "自然分數": 68, "社會分數": 70},
    {"姓名": "曹育銘", "國文分數": 85, "數學分數": 87, "英文分數": 84, "自然分數": 86, "社會分數": 85},
    {"姓名": "嚴佳穎", "國文分數": 74, "數學分數": 71, "英文分數": 75, "自然分數": 73, "社會分數": 72},
    {"姓名": "游建國", "國文分數": 90, "數學分數": 91, "英文分數": 88, "自然分數": 89, "社會分數": 90},
    {"姓名": "金雅琴", "國文分數": 78, "數學分數": 76, "英文分數": 79, "自然分數": 77, "社會分數": 78},
    {"姓名": "歐陽正", "國文分數": 81, "數學分數": 80, "英文分數": 82, "自然分數": 83, "社會分數": 81},
    {"姓名": "倪子平", "國文分數": 92, "數學分數": 94, "英文分數": 90, "自然分數": 93, "社會分數": 91},
    {"姓名": "駱美雲", "國文分數": 66, "數學分數": 63, "英文分數": 68, "自然分數": 65, "社會分數": 67},
    {"姓名": "樊嘉宏", "國文分數": 83, "數學分數": 85, "英文分數": 82, "自然分數": 84, "社會分數": 83},
    {"姓名": "藍婉婷", "國文分數": 73, "數學分數": 75, "英文分數": 72, "自然分數": 74, "社會分數": 73},
    {"姓名": "邵冠名", "國文分數": 95, "數學分數": 97, "英文分數": 94, "自然分數": 96, "社會分數": 95},
    {"姓名": "龍美玲", "國文分數": 70, "數學分數": 68, "英文分數": 72, "自然分數": 69, "社會分數": 71},
    {"姓名": "鞏建勳", "國文分數": 88, "數學分數": 86, "英文分數": 89, "自然分數": 87, "社會分數": 88},
    {"姓名": "辛雅婷", "國文分數": 62, "數學分數": 65, "英文分數": 60, "自然分數": 63, "社會分數": 64},
    {"姓名": "辜政弘", "國文分數": 79, "數學分數": 81, "英文分數": 78, "自然分數": 80, "社會分數": 79},
    {"姓名": "萬家慧", "國文分數": 96, "數學分數": 95, "英文分數": 97, "自然分數": 94, "社會分數": 96},
    {"姓名": "屈健庭", "國文分數": 64, "數學分數": 61, "英文分數": 66, "自然分數": 62, "社會分數": 65},
    {"姓名": "閔美雲", "國文分數": 84, "數學分數": 82, "英文分數": 85, "自然分數": 83, "社會分數": 84},
    {"姓名": "祝承翰", "國文分數": 76, "數學分數": 78, "英文分數": 75, "自然分數": 77, "社會分數": 76},
    {"姓名": "紀佳蓉", "國文分數": 91, "數學分數": 93, "英文分數": 90, "自然分數": 92, "社會分數": 91},
    {"姓名": "舒銘宏", "國文分數": 67, "數學分數": 69, "英文分數": 66, "自然分數": 68, "社會分數": 67}
]

score_keys = ["國文分數", "數學分數", "英文分數", "自然分數", "社會分數"]
for student in student_scores:
    total = sum(student[key] for key in score_keys)
    avg = total / len(score_keys)
    student["總分"] = total
    student["平均"] = round(avg, 2)
    print(f'{student["姓名"]}: 總分={total}, 平均={student["平均"]}')

print("\n前三名：")
top_three = sorted(student_scores, key=lambda s: s["總分"], reverse=True)[:3]
for rank, student in enumerate(top_three, start=1):
    print(f'{rank}. {student["姓名"]} - 總分={student["總分"]}, 平均={student["平均"]}')
# Out:
# 王小明: 總分=433, 平均=86.6
# 李小華: 總分=368, 平均=73.6
# 張大同: 總分=454, 平均=90.8
# 陳欣怡: 總分=349, 平均=69.8
# 林志豪: 總分=412, 平均=82.4
# 黃雅婷: 總分=475, 平均=95.0
# 吳建宏: 總分=354, 平均=70.8
# 蔡佩珊: 總分=436, 平均=87.2
# 許家豪: 總分=296, 平均=59.2
# 鄭淑芬: 總分=396, 平均=79.2
# 謝承翰: 總分=455, 平均=91.0
# 郭美玲: 總分=423, 平均=84.6
# 曾冠傑: 總分=369, 平均=73.8
# 彭詩涵: 總分=478, 平均=95.6
# 詹銘宏: 總分=329, 平均=65.8
# 盧佳蓉: 總分=413, 平均=82.6
# 丁昱翔: 總分=356, 平均=71.2
# 蘇婉君: 總分=443, 平均=88.6
# 魏廷翰: 總分=465, 平均=93.0
# 薛雅筑: 總分=387, 平均=77.4
# 何智偉: 總分=430, 平均=86.0
# 羅秋玲: 總分=318, 平均=63.6
# 江政廷: 總分=405, 平均=81.0
# 童郁芬: 總分=468, 平均=93.6
# 廖健文: 總分=360, 平均=72.0
# 邱美惠: 總分=435, 平均=87.0
# 柯文祥: 總分=294, 平均=58.8
# 鐘惠萍: 總分=408, 平均=81.6
# 尤冠宇: 總分=483, 平均=96.6
# 阮詩琴: 總分=344, 平均=68.8
# 曹育銘: 總分=427, 平均=85.4
# 嚴佳穎: 總分=365, 平均=73.0
# 游建國: 總分=448, 平均=89.6
# 金雅琴: 總分=388, 平均=77.6
# 歐陽正: 總分=407, 平均=81.4
# 倪子平: 總分=460, 平均=92.0
# 駱美雲: 總分=329, 平均=65.8
# 樊嘉宏: 總分=417, 平均=83.4
# 藍婉婷: 總分=367, 平均=73.4
# 邵冠名: 總分=477, 平均=95.4
# 龍美玲: 總分=350, 平均=70.0
# 鞏建勳: 總分=438, 平均=87.6
# 辛雅婷: 總分=314, 平均=62.8
# ...
