# %%
#建立工廠

class Person:
    def __init__(self): #自訂的初始化
        print("初始化:一個新的人被建立了")

# %%
p1 = Person()
type(p1)
# Out:
# 初始化:一個新的人被建立了
# __main__.Person

# %%
class Person:
    def __init__(self,name):
        #建立一個attribute
        self.name = name

# %%
p2 = Person("robert")
p2.name
# Out:
# 'robert'

# %%
p3 = Person("jenny")
p3.name
# Out:
# 'jenny'
