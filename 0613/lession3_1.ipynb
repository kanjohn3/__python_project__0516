# %%
import pandas as pd

df = pd.DataFrame({
    "學生姓名": ["王小明", "趙冠宇", "李小華", "趙冠宇"],
    "分數": [80, 95, 72, 88]
})

df[df["學生姓名"] == "趙冠宇"]
# Out:
#   學生姓名  分數
# 1  趙冠宇  95
# 3  趙冠宇  88

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

font = FontProperties(fname="C:/Windows/Fonts/msjh.ttc")

# 讀取 CSV
df = pd.read_csv("0613/考試分數_3年6班.csv")

# 篩選趙冠宇的資料
zhao = df[df["學生姓名"] == "趙冠宇"]

# 取出各科成績
scores = zhao.iloc[0][["語文", "數學", "英語", "物理", "化學"]]
print(scores.index)
print(scores.values)
